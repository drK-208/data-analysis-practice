# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbr
df = pd.read_csv('./sample_data/world-data-2023.csv')

# %%
df.head(5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
df.dropna()
# Out:
#             Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0       Afghanistan               60           AF                58.10%
# 1           Albania              105           AL                43.10%
# 2           Algeria               18           DZ                17.40%
# 4            Angola               26           AO                47.50%
# 6         Argentina               17           AR                54.30%
# ..              ...              ...          ...                   ...
# 185  United Kingdom              281           GB                71.70%
# 186   United States               36           US                44.40%
# 187         Uruguay               20           UY                82.60%
# 191         Vietnam              314           VN                39.30%
# 193          Zambia               25           ZM                32.10%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# ...

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Country                                      0
# Density\n(P/Km2)                             0
# Abbreviation                                 0
# Agricultural Land( %)                        0
# Land Area(Km2)                               0
# Armed Forces size                            0
# Birth Rate                                   0
# Calling Code                                 0
# Capital/Major City                           0
# Co2-Emissions                                0
# CPI                                          0
# CPI Change (%)                               0
# Currency-Code                                0
# Fertility Rate                               0
# Forested Area (%)                            0
# Gasoline Price                               0
# GDP                                          0
# Gross primary education enrollment (%)       0
# Gross tertiary education enrollment (%)      0
# Infant mortality                             0
# ...

# %%
df['Population'] = df['Population'].str.replace(',', '')

# %%
for i, row in df.iterrows():
  if   int(row['Population']) > 300000000:

    print(row['Country'])
# Out:
# China
# India
# United States

# %%
ndf = df[['Birth Rate', 'Fertility Rate']]
sbr.scatterplot(x = 'Birth Rate', y = 'Fertility Rate', data=df)
# Out:
# 46.08

# %%
max = df['Birth Rate'].max()
df[df['Birth Rate'] == max]
# Out:
#     Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 125   Niger               19           NE                36.10%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 125      1,267,000            10,000       46.08         227.0
#
#     Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 125             Niamey         2,017  ...                           52.30%
#
#     Physicians per thousand  Population  \
# 125                    0.04  23,310,715
#
#      Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 125                                     72.00%          11.80%         47.20%
#
#     Unemployment rate Urban_population   Latitude  Longitude
# 125             0.47%        3,850,231  17.607789   8.081666
#
# [1 rows x 35 columns]

# %%
plt.figure(figsize=(20,10))
ax = sbr.barplot(x = 'Country', y = 'Birth Rate', data=df.iloc[:len(df)//2])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Afghanistan'),
#  Text(1, 0, 'Albania'),
#  Text(2, 0, 'Algeria'),
#  Text(3, 0, 'Andorra'),
#  Text(4, 0, 'Angola'),
#  Text(5, 0, 'Antigua and Barbuda'),
#  Text(6, 0, 'Argentina'),
#  Text(7, 0, 'Armenia'),
#  Text(8, 0, 'Australia'),
#  Text(9, 0, 'Austria'),
#  Text(10, 0, 'Azerbaijan'),
#  Text(11, 0, 'The Bahamas'),
#  Text(12, 0, 'Bahrain'),
#  Text(13, 0, 'Bangladesh'),
#  Text(14, 0, 'Barbados'),
#  Text(15, 0, 'Belarus'),
#  Text(16, 0, 'Belgium'),
#  Text(17, 0, 'Belize'),
#  Text(18, 0, 'Benin'),
#  Text(19, 0, 'Bhutan'),
#  Text(20, 0, 'Bolivia'),
#  Text(21, 0, 'Bosnia and Herzegovina'),
#  Text(22, 0, 'Botswana'),
#  Text(23, 0, 'Brazil'),
#  Text(24, 0, 'Brunei'),
#  Text(25, 0, 'Bulgaria'),
#  Text(26, 0, 'Burkina Faso'),
#  Text(27, 0, 'Burundi'),
#  Text(28, 0, 'Ivory Coast'),
#  Text(29, 0, 'Cape Verde'),
#  Text(30, 0, 'Cambodia'),
#  Text(31, 0, 'Cameroon'),
#  Text(32, 0, 'Canada'),
#  Text(33, 0, 'Central African Republic'),
# ...

# %%
plt.figure(figsize=(20,10))
ax2 = sbr.barplot(x = 'Country', y = 'Birth Rate', data=df.iloc[len(df)//2:])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Libya'),
#  Text(1, 0, 'Liechtenstein'),
#  Text(2, 0, 'Lithuania'),
#  Text(3, 0, 'Luxembourg'),
#  Text(4, 0, 'Madagascar'),
#  Text(5, 0, 'Malawi'),
#  Text(6, 0, 'Malaysia'),
#  Text(7, 0, 'Maldives'),
#  Text(8, 0, 'Mali'),
#  Text(9, 0, 'Malta'),
#  Text(10, 0, 'Marshall Islands'),
#  Text(11, 0, 'Mauritania'),
#  Text(12, 0, 'Mauritius'),
#  Text(13, 0, 'Mexico'),
#  Text(14, 0, 'Federated States of Micronesia'),
#  Text(15, 0, 'Moldova'),
#  Text(16, 0, 'Monaco'),
#  Text(17, 0, 'Mongolia'),
#  Text(18, 0, 'Montenegro'),
#  Text(19, 0, 'Morocco'),
#  Text(20, 0, 'Mozambique'),
#  Text(21, 0, 'Myanmar'),
#  Text(22, 0, 'Namibia'),
#  Text(23, 0, 'Nauru'),
#  Text(24, 0, 'Nepal'),
#  Text(25, 0, 'Netherlands'),
#  Text(26, 0, 'New Zealand'),
#  Text(27, 0, 'Nicaragua'),
#  Text(28, 0, 'Niger'),
#  Text(29, 0, 'Nigeria'),
#  Text(30, 0, 'North Korea'),
#  Text(31, 0, 'North Macedonia'),
#  Text(32, 0, 'Norway'),
#  Text(33, 0, 'Oman'),
#  Text(34, 0, 'Pakistan'),
# ...
